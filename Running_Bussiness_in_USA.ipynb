# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
df=pd.read_csv("/content/dataset/Listing_of_Active_Businesses.csv")
df.head()
# Out:
# <ipython-input-7-ad15adbec0a9>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/dataset/Listing_of_Active_Businesses.csv")
#   LOCATION ACCOUNT #             BUSINESS NAME                 DBA NAME  \
# 0  0002470296-0003-7                KOMODO LLC                   KOMODO
# 1  0002829017-0001-5      RICHARD JOHN SHERMAN                      NaN
# 2  0003260354-0001-2  SOCAL DEMOLITION COMPANY                      NaN
# 3  0003266830-0001-1         MAGICMATCH AI LLC                      NaN
# 4  0003267028-0001-6         FRANCISCO ALVAREZ  MOBILE PROTECTION GUARD
#
#                         STREET ADDRESS           CITY    ZIP CODE  \
# 0                      235 MAIN STREET         VENICE  90291-5221
# 1                 2010 LA BREA TERRACE    LOS ANGELES  90046-2314
# 2                    319 W 18TH STREET  NATIONAL CITY  91950-5525
# ...

# %%
df=pd.read_csv("/content/dataset/Listing_of_Active_Businesses.csv")
df.tail()
# Out:
# <ipython-input-9-ca6ed0253309>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/dataset/Listing_of_Active_Businesses.csv")
#       LOCATION ACCOUNT #               BUSINESS NAME       DBA NAME  \
# 99345  0003325389-0001-2           TAMAYA DE LA ROSA  MY SIDE CHICK
# 99346  0003393309-0001-3                  LAPROM INC            NaN
# 99347  0002741936-0001-1  ENRIQUE ORTIZ DE LANDAZURI     RAW SPIRIT
# 99348  0002882986-0001-7                TIMOTHY GAER            NaN
# 99349  0000003266-0001-6                KYUNG MO HAN            NaN
#
#                        STREET ADDRESS             CITY    ZIP CODE  \
# 99345                 2509 TOPAZ LANE        LANCASTER  93535-5604
# 99346            6865 VINELAND AVENUE  NORTH HOLLYWOOD  91605-6410
# 99347           2345 TUNA CANYON ROAD          TOPANGA  90290-3452
# 99348  5825   RESEDA BLVD   UNIT #231          TARZANA  91356-2019
# ...

# %%
df.dtypes
# Out:
# LOCATION ACCOUNT #            object
# BUSINESS NAME                 object
# DBA NAME                      object
# STREET ADDRESS                object
# CITY                          object
# ZIP CODE                      object
# LOCATION DESCRIPTION          object
# MAILING ADDRESS               object
# MAILING CITY                  object
# MAILING ZIP CODE              object
# NAICS                        float64
# PRIMARY NAICS DESCRIPTION     object
# COUNCIL DISTRICT             float64
# LOCATION START DATE           object
# LOCATION END DATE            float64
# LOCATION                      object
# dtype: object
