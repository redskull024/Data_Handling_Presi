# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
df=pd.read_csv("/content/Datasets/BL-Flickr-Images-Book (1).csv")
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
df=pd.read_csv("/content/Datasets/BL-Flickr-Images-Book (1).csv")
df.tail()
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 8282     4158088               NaN               London                1838
# 8283     4158128               NaN                Derby            1831, 32
# 8284     4159563               NaN               London           [1806]-22
# 8285     4159587               NaN  Newcastle upon Tyne                1834
# 8286     4160339               NaN               London             1834-43
#
#                     Publisher  \
# 8282                      NaN
# 8283          M. Mozley & Son
# 8284  T. Cadell and W. Davies
# 8285         Mackenzie & Dent
# 8286                      NaN
#
#                                                   Title  \
# 8282  The Parochial History of Cornwall, founded on,...
# 8283  The History and Gazetteer of the County of Der...
# 8284  Magna Britannia; being a concise topographical...
# 8285  An historical, topographical and descriptive v...
# ...

# %%
df.dtypes
# Out:
# Identifier                  int64
# Edition Statement          object
# Place of Publication       object
# Date of Publication        object
# Publisher                  object
# Title                      object
# Author                     object
# Contributors               object
# Corporate Author          float64
# Corporate Contributors    float64
# Former owner               object
# Engraver                  float64
# Issuance type              object
# Flickr URL                 object
# Shelfmarks                 object
# dtype: object

# %%
to_drop=['Edition Statement','Shelfmarks']
df.drop(to_drop, inplace= True, axis = 1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-ce909146d5b9> in <cell line: 2>()
#       1 to_drop=['Edition Statement','Shelfmarks']
# ----> 2 df.drop(to_drop, inplace= True, axis = 1)
#       3 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df.set_index('Identifier',inplace=True)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
# @title Date of Publication vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['Date of Publication']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'Date of Publication'}, axis=1)
              .sort_values('Date of Publication', ascending=True))
  xs = counted['Date of Publication']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date of Publication', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Issuance type')):
  _plot_series(series, series_name, i)
  fig.legend(title='Issuance type', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date of Publication')
_ = plt.ylabel('count()')

# %%
unwanted_charecters=['[',',','-']
def clean_dates(item):
  dop=str(item.loc['Date of Publication'])
  if dop == 'nan' or dop[0] =='[':
    return np.NaN
  for charecter in unwanted_charecters:
    if charecter in dop:
      charecter_index=dop.find(charecter)
      dop=dop[:charecter_index]
  return dop
df['Date of Publication']=df.apply(clean_dates,axis=1)

# %%
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...
